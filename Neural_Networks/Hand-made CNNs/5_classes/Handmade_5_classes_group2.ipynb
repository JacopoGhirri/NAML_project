# %% [markdown]
# ##5 classes: blues, reggae, jazz, country, pop

# %%
#importing google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
#setting the working directory
# %cd /gdrive/MyDrive/Colab Notebooks/NAML/Project
# Out:
# /gdrive/MyDrive/Colab Notebooks/NAML/Project

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
import librosa
import os

tfk = tf.keras
tfkl = tf.keras.layers
seed = 42

# %%
dataset = []
# genres = {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

genres = {  'blues': 0, 'reggae': 1, 'jazz': 2,  'country': 3,  'pop': 4}

n_genres=5

for genre, genre_number in genres.items():
    for filename in os.listdir(f'dataset_old/genres/{genre}'):
        songname = f'dataset_old/genres/{genre}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=29.7)
        ps = librosa.feature.melspectrogram(y=y, sr=sr, hop_length = 256, n_fft = 512)
        ps = librosa.power_to_db(ps**2)
        dataset.append( (ps, genre_number) )
    print(str(genre+' done'))
# Out:
# blues done
# reggae done
# jazz done
# country done
# pop done

# %%
order = np.arange(start = 0, stop = 100, step = 1)

np.random.seed(42)

training = []
validation = []
test = []

for i in range(5):
  shuffle = np.random.permutation(order)
  for k in range(70):
    training.append(dataset[i*100 + shuffle[k]])
  for l in range(20):
    validation.append(dataset[i*100 + shuffle[l+70]])
  for m in range(10):
    test.append(dataset[i*100 + shuffle[m+90]])

# %%
X_train, Y_train = zip(*training)
X_valid, Y_valid = zip(*validation)
X_test, Y_test = zip(*test)

X_train = np.array([x.reshape( (128, 2559, 1) ) for x in X_train])
X_valid = np.array([x.reshape( (128, 2559, 1) ) for x in X_valid])
X_test = np.array([x.reshape( (128, 2559, 1) ) for x in X_test])

Y_train = np.array(tfk.utils.to_categorical(Y_train, n_genres))
Y_valid = np.array(tfk.utils.to_categorical(Y_valid, n_genres))
Y_test = np.array(tfk.utils.to_categorical(Y_test, n_genres))

# %% [markdown]
# ### 6 conv e doppi conv + max pool, last GAP, 2 dense, square filt

# %%
def build_model(input_shape, n_units):
# Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        filters=4,
        kernel_size=(5, 5),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    conv1_2 = tfkl.Conv2D(
        filters=8,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv1)
    pool1 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv1_2)

    conv2 = tfkl.Conv2D(
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    conv2_2 = tfkl.Conv2D(
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv2)
    pool2 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv2_2)

    conv3 = tfkl.Conv2D(
        filters=32,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    conv4_2 = tfkl.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv4)
    pool4 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv4_2)

    conv5 = tfkl.Conv2D(
        filters=128,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv5)

    conv6 = tfkl.Conv2D(
        filters=286,
        kernel_size=(1,1),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool5)
    

    global_average = tfkl.GlobalAveragePooling2D(name = 'GAP')(conv6)
    global_average = tfkl.Dropout(0.3, seed=seed)(global_average)
    
    classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(global_average)
    #flattening_layer = tfkl.Flatten(name='Flatten')(pool5)
    #flattening_layer = tfkl.Dropout(0.2, seed=seed)(flattening_layer)
    #classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(flattening_layer)
    
    classifier_layer = tfkl.Dropout(0.3, seed=seed)(classifier_layer)
    classifier_layer_2 = tfkl.Dense(units=32, name='Classifier_2', activation='relu')(classifier_layer)
    classifier_layer_2 = tfkl.Dropout(0.3, seed=seed)(classifier_layer_2)
    output_layer = tfkl.Dense(units=n_units, activation='softmax', name='Output')(classifier_layer_2)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model

    return model

# %%
input_shape = (128, 2559, 1)

model = build_model(input_shape, n_genres)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 128, 2559, 1)]    0
#
#  conv2d (Conv2D)             (None, 128, 2559, 4)      104
#
#  conv2d_1 (Conv2D)           (None, 128, 2559, 8)      296
#
#  max_pooling2d (MaxPooling2D  (None, 64, 1279, 8)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 1279, 16)      1168
#
#  conv2d_3 (Conv2D)           (None, 64, 1279, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 639, 16)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 639, 32)       4640
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 319, 32)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 319, 64)       18496
#
#  conv2d_6 (Conv2D)           (None, 16, 319, 64)       36928
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 159, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 159, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 79, 128)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 79, 286)        36894
#
#  GAP (GlobalAveragePooling2D  (None, 286)              0
#  )
#
#  dropout (Dropout)           (None, 286)               0
#
#  Classifier (Dense)          (None, 64)                18368
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  Classifier_2 (Dense)        (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  Output (Dense)              (None, 5)                 165
#
# =================================================================
# Total params: 195,315
# Trainable params: 195,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True)
adaptive_LR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-4)

standard_history = model.fit(
    x = X_train,
    y = Y_train,
    epochs = 500,
    batch_size = 64,
    validation_data= (X_valid, Y_valid),
    callbacks = [early_stopping, adaptive_LR]
    )
# Out:
# Epoch 1/500
# 6/6 [==============================] - 20s 2s/step - loss: 1.6402 - accuracy: 0.1857 - val_loss: 1.6089 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/500
# 6/6 [==============================] - 5s 901ms/step - loss: 1.6113 - accuracy: 0.1971 - val_loss: 1.6075 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/500
# 6/6 [==============================] - 5s 902ms/step - loss: 1.6117 - accuracy: 0.2143 - val_loss: 1.6067 - val_accuracy: 0.2100 - lr: 0.0010
# Epoch 4/500
# 6/6 [==============================] - 5s 900ms/step - loss: 1.6050 - accuracy: 0.2229 - val_loss: 1.6051 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/500
# 6/6 [==============================] - 5s 896ms/step - loss: 1.6168 - accuracy: 0.1686 - val_loss: 1.6061 - val_accuracy: 0.2400 - lr: 0.0010
# Epoch 6/500
# 6/6 [==============================] - 5s 910ms/step - loss: 1.6064 - accuracy: 0.2200 - val_loss: 1.6053 - val_accuracy: 0.2800 - lr: 0.0010
# Epoch 7/500
# 6/6 [==============================] - 5s 895ms/step - loss: 1.5973 - accuracy: 0.2571 - val_loss: 1.5968 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 8/500
# 6/6 [==============================] - 5s 892ms/step - loss: 1.5982 - accuracy: 0.2229 - val_loss: 1.5895 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 9/500
# 6/6 [==============================] - 5s 890ms/step - loss: 1.5827 - accuracy: 0.2114 - val_loss: 1.5671 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 10/500
# 6/6 [==============================] - 5s 894ms/step - loss: 1.5622 - accuracy: 0.2400 - val_loss: 1.5317 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch
500
# 6/6 [==============================] - 5s 887ms/step - loss: 0.6385 - accuracy: 0.7543 - val_loss: 0.9738 - val_accuracy: 0.6200 - lr: 1.0000e-04
# Epoch 116/500
# 6/6 [==============================] - 5s 891ms/step - loss: 0.6306 - accuracy: 0.7829 - val_loss: 0.9697 - val_accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 117/500
# 6/6 [==============================] - 5s 892ms/step - loss: 0.6069 - accuracy: 0.7629 - val_loss: 0.9564 - val_accuracy: 0.6700 - lr: 1.0000e-04
# Epoch 118/500
# 6/6 [==============================] - 5s 886ms/step - loss: 0.6070 - accuracy: 0.7657 - val_loss: 0.9845 - val_accuracy: 0.6300 - lr: 1.0000e-04
# Epoch 119/500
# 6/6 [==============================] - 5s 891ms/step - loss: 0.5889 - accuracy: 0.7629 - val_loss: 1.0661 - val_accuracy: 0.6300 - lr: 1.0000e-04
# Epoch 120/500
# 6/6 [==============================] - 5s 889ms/step - loss: 0.6145 - accuracy: 0.7771 - val_loss: 0.9700 - val_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 121/500
# 6/6 [==============================] - 5s 891ms/step - loss: 0.6057 - accuracy: 0.7800 - val_loss: 1.0050 - val_accuracy: 0.6300 - lr: 1.0000e-04
# Epoch 122/500
# 6/6 [==============================] - 5s 894ms/step - loss: 0.5557 - accuracy: 0.7971 - val_loss: 0.9832 - val_accuracy: 0.6600 - lr: 1.0000e-04
# Epoch 123/500
# 6/6 [==============================] - 5s 887ms/step - loss: 0.5574 - accuracy: 0.7800 - val_loss: 1.0125 - val_accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 124/500
# 6/6 [==============================] - 5s 891ms/step - loss: 0.6229 - accuracy: 0.7600 - val_loss: 1.0171 - val_accuracy: 0.6300 - lr: 1.0000e-04

# %%
predictions = model.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T)#, xticklabels=list(labels.values()), yticklabels=list(labels.values()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.76
# Precision: 0.8043
# Recall: 0.76
# F1: 0.7656

# %% [markdown]
# ###As before but rect filt

# %%
def build_model_1(input_shape, n_units):
# Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        filters=4,
        kernel_size=(3, 5),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    conv1_2 = tfkl.Conv2D(
        filters=8,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv1)
    pool1 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv1_2)

    conv2 = tfkl.Conv2D(
        filters=16,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    conv2_2 = tfkl.Conv2D(
        filters=16,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv2)
    pool2 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv2_2)

    conv3 = tfkl.Conv2D(
        filters=32,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        filters=64,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    conv4_2 = tfkl.Conv2D(
        filters=64,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv4)
    pool4 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv4_2)

    conv5 = tfkl.Conv2D(
        filters=128,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv5)

    conv6 = tfkl.Conv2D(
        filters=286,
        kernel_size=(1,2),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool5)
    

    global_average = tfkl.GlobalAveragePooling2D(name = 'GAP')(conv6)
    global_average = tfkl.Dropout(0.3, seed=seed)(global_average)
    
    classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(global_average)
    #flattening_layer = tfkl.Flatten(name='Flatten')(pool5)
    #flattening_layer = tfkl.Dropout(0.2, seed=seed)(flattening_layer)
    #classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(flattening_layer)
    
    classifier_layer = tfkl.Dropout(0.3, seed=seed)(classifier_layer)
    classifier_layer_2 = tfkl.Dense(units=32, name='Classifier_2', activation='relu')(classifier_layer)
    classifier_layer_2 = tfkl.Dropout(0.3, seed=seed)(classifier_layer_2)
    output_layer = tfkl.Dense(units=n_units, activation='softmax', name='Output')(classifier_layer_2)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model

    return model

# %%
input_shape = (128, 2559, 1)

model_1 = build_model_1(input_shape, n_genres)

model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 128, 2559, 1)]    0
#
#  conv2d_9 (Conv2D)           (None, 128, 2559, 4)      64
#
#  conv2d_10 (Conv2D)          (None, 128, 2559, 8)      200
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 1279, 8)      0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 64, 1279, 16)      784
#
#  conv2d_12 (Conv2D)          (None, 64, 1279, 16)      1552
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 639, 16)      0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 639, 32)       3104
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 319, 32)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 319, 64)       12352
#
#  conv2d_15 (Conv2D)          (None, 16, 319, 64)       24640
#
#  max_pooling2d_8 (MaxPooling  (None, 8, 159, 64)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 8, 159, 128)       49280
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 79, 128)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 4, 79, 286)        73502
#
#  GAP (GlobalAveragePooling2D  (None, 286)              0
#  )
#
#  dropout_3 (Dropout)         (None, 286)               0
#
#  Classifier (Dense)          (None, 64)                18368
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  Classifier_2 (Dense)        (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  Output (Dense)              (None, 5)                 165
#
# =================================================================
# Total params: 186,091
# Trainable params: 186,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True)
adaptive_LR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-4)

standard_history_1 = model_1.fit(
    x = X_train,
    y = Y_train,
    epochs = 500,
    batch_size = 64,
    validation_data= (X_valid, Y_valid),
    callbacks = [early_stopping, adaptive_LR]
    )
# Out:
# Epoch 1/500
# 6/6 [==============================] - 14s 2s/step - loss: 1.6213 - accuracy: 0.2343 - val_loss: 1.6065 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/500
# 6/6 [==============================] - 5s 858ms/step - loss: 1.6270 - accuracy: 0.1629 - val_loss: 1.6064 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/500
# 6/6 [==============================] - 5s 855ms/step - loss: 1.6070 - accuracy: 0.2057 - val_loss: 1.6028 - val_accuracy: 0.2700 - lr: 0.0010
# Epoch 4/500
# 6/6 [==============================] - 5s 856ms/step - loss: 1.5975 - accuracy: 0.2343 - val_loss: 1.5910 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/500
# 6/6 [==============================] - 5s 857ms/step - loss: 1.5946 - accuracy: 0.2771 - val_loss: 1.5654 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 6/500
# 6/6 [==============================] - 5s 859ms/step - loss: 1.5716 - accuracy: 0.2686 - val_loss: 1.5483 - val_accuracy: 0.2800 - lr: 0.0010
# Epoch 7/500
# 6/6 [==============================] - 5s 854ms/step - loss: 1.5287 - accuracy: 0.2800 - val_loss: 1.5034 - val_accuracy: 0.3900 - lr: 0.0010
# Epoch 8/500
# 6/6 [==============================] - 5s 850ms/step - loss: 1.5095 - accuracy: 0.3200 - val_loss: 1.4788 - val_accuracy: 0.3700 - lr: 0.0010
# Epoch 9/500
# 6/6 [==============================] - 5s 852ms/step - loss: 1.4763 - accuracy: 0.3400 - val_loss: 1.4544 - val_accuracy: 0.3800 - lr: 0.0010
# Epoch 10/500
# 6/6 [==============================] - 5s 851ms/step - loss: 1.4767 - accuracy: 0.3600 - val_loss: 1.4911 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 11/500
# 6/6 [==============================] - 5s 856ms/step - loss: 1.4832 - accuracy: 0.3314 - val_loss: 1.4929 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 12/500
# 6/6 [==============================] - 5s 849ms/step - loss: 1.4384 - accuracy: 0.3429 - val_loss: 1.4015 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch
500
# 6/6 [==============================] - 5s 858ms/step - loss: 0.5042 - accuracy: 0.7886 - val_loss: 0.7739 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 211/500
# 6/6 [==============================] - 5s 861ms/step - loss: 0.5358 - accuracy: 0.7600 - val_loss: 0.7864 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 212/500
# 6/6 [==============================] - 5s 859ms/step - loss: 0.5536 - accuracy: 0.7743 - val_loss: 0.7807 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 213/500
# 6/6 [==============================] - 5s 855ms/step - loss: 0.5433 - accuracy: 0.7743 - val_loss: 0.8105 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 214/500
# 6/6 [==============================] - 5s 859ms/step - loss: 0.5134 - accuracy: 0.7714 - val_loss: 0.7956 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 215/500
# 6/6 [==============================] - 5s 855ms/step - loss: 0.5345 - accuracy: 0.7600 - val_loss: 0.7763 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 216/500
# 6/6 [==============================] - 5s 861ms/step - loss: 0.5181 - accuracy: 0.7657 - val_loss: 0.7758 - val_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 217/500
# 6/6 [==============================] - 5s 859ms/step - loss: 0.4998 - accuracy: 0.7857 - val_loss: 0.7697 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 218/500
# 6/6 [==============================] - 5s 856ms/step - loss: 0.5148 - accuracy: 0.7943 - val_loss: 0.8284 - val_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 219/500
# 6/6 [==============================] - 5s 861ms/step - loss: 0.5327 - accuracy: 0.7829 - val_loss: 0.7822 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 220/500
# 6/6 [==============================] - 5s 859ms/step - loss: 0.5179 - accuracy: 0.7686 - val_loss: 0.8308 - val_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 221/500
# 6/6 [==============================] - 5s 858ms/step - loss: 0.5211 - accuracy: 0.7971 - val_loss: 0.7709 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 222/500
# 6/6 [==============================] - 5s 859ms/step - loss: 0.5348 - accuracy: 0.7800 - val_loss: 0.7752 - val_accuracy: 0.7400 - lr: 1.0000e-04

# %%
predictions_1 = model_1.predict(X_test)

# Compute the confusion matrix
cm_1 = confusion_matrix(np.argmax(Y_test, axis=-1), np.argmax(predictions_1, axis=-1))

# Compute the classification metrics
accuracy_1 = accuracy_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_1, axis=-1))
precision_1 = precision_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_1, axis=-1), average='macro')
recall_1 = recall_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_1, axis=-1), average='macro')
f1_1 = f1_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_1, axis=-1), average='macro')
print('Accuracy:',accuracy_1.round(4))
print('Precision:',precision_1.round(4))
print('Recall:',recall_1.round(4))
print('F1:',f1_1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_1.T)#, xticklabels=list(labels.values()), yticklabels=list(labels.values()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.82
# Precision: 0.8327
# Recall: 0.82
# F1: 0.8235

# %% [markdown]
# ### 5 conv + max pool, 2 dense, square filt but last 2 rect

# %%
def build_model_2(input_shape, n_units):
# Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    pool1 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv1)

    conv2 = tfkl.Conv2D(
        filters=32,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    pool2 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv2)

    conv3 = tfkl.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    pool4 = tfkl.MaxPooling2D(
        pool_size = (2, 3)
    )(conv4)

    conv5 = tfkl.Conv2D(
        filters=128,
        kernel_size=(2, 2),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        pool_size = (2, 3)
    )(conv5)


    flattening_layer = tfkl.Flatten(name='Flatten')(pool5)
    flattening_layer = tfkl.Dropout(0.2, seed=seed)(flattening_layer)
    classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(flattening_layer)
    classifier_layer = tfkl.Dropout(0.2, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=n_units, activation='softmax', name='Output')(classifier_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model

    return model

# %%
input_shape = (128, 2559, 1)

model_2 = build_model_2(input_shape, n_genres)

model_2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 128, 2559, 1)]    0
#
#  conv2d_18 (Conv2D)          (None, 128, 2559, 16)     160
#
#  max_pooling2d_10 (MaxPoolin  (None, 64, 1279, 16)     0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 64, 1279, 32)      4640
#
#  max_pooling2d_11 (MaxPoolin  (None, 32, 639, 32)      0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 32, 639, 64)       18496
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 319, 64)      0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 16, 319, 64)       36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 8, 106, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 8, 106, 128)       32896
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 35, 128)       0
#  g2D)
#
#  Flatten (Flatten)           (None, 17920)             0
#
#  dropout_6 (Dropout)         (None, 17920)             0
#
#  Classifier (Dense)          (None, 64)                1146944
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  Output (Dense)              (None, 5)                 325
#
# =================================================================
# Total params: 1,240,389
# Trainable params: 1,240,389
# Non-trainable params: 0
# _________________________________________________________________

# %%
#first_callbacks = create_folders_and_callbacks(model_name='first')
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=2)

standard_history_2 = model_2.fit(
    x = X_train,
    y = Y_train,
    epochs = 90,
    batch_size = 64,
    validation_data= (X_valid, Y_valid),
    callbacks = [early_stopping]
    )
# Out:
# Epoch 1/90
# 6/6 [==============================] - 12s 1s/step - loss: 10.2983 - accuracy: 0.1886 - val_loss: 2.1474 - val_accuracy: 0.2000
# Epoch 2/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.7809 - accuracy: 0.2143 - val_loss: 1.6011 - val_accuracy: 0.2500
# Epoch 3/90
# 6/6 [==============================] - 4s 667ms/step - loss: 1.6083 - accuracy: 0.2514 - val_loss: 1.5709 - val_accuracy: 0.3100
# Epoch 4/90
# 6/6 [==============================] - 4s 670ms/step - loss: 1.5711 - accuracy: 0.3029 - val_loss: 1.5679 - val_accuracy: 0.3700
# Epoch 5/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.5517 - accuracy: 0.3200 - val_loss: 1.4809 - val_accuracy: 0.4900
# Epoch 6/90
# 6/6 [==============================] - 4s 664ms/step - loss: 1.4807 - accuracy: 0.4314 - val_loss: 1.4811 - val_accuracy: 0.4400
# Epoch 7/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.4153 - accuracy: 0.4343 - val_loss: 1.5535 - val_accuracy: 0.3400
# Epoch 8/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.4897 - accuracy: 0.4086 - val_loss: 1.4405 - val_accuracy: 0.4800
# Epoch 9/90
# 6/6 [==============================] - 4s 661ms/step - loss: 1.4066 - accuracy: 0.4286 - val_loss: 1.3654 - val_accuracy: 0.5000
# Epoch 10/90
# 6/6 [==============================] - 4s 662ms/step - loss: 1.3471 - accuracy: 0.4600 - val_loss: 1.2785 - val_accuracy: 0.4800
# Epoch 11/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.2878 - accuracy: 0.4629 - val_loss: 1.2327 - val_accuracy: 0.5200
# Epoch 12/90
# 6/6 [==============================] - 4s 666ms/step - loss: 1.2500 - accuracy: 0.4971 - val_loss: 1.2241 - val_accuracy: 0.5000
# Epoch 13/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.2331 - accuracy: 0.4857 - val_loss: 1.1765 - val_accuracy: 0.5200
# Epoch 14/90
# 6/6 [==============================] - 4s 659ms/step - loss: 1.2271 - accuracy: 0.5114 - val_loss: 1.1919 - val_accuracy: 0.4800
# Epoch 15/90
# 6/6 [==============================] - 4s 663ms/step - loss: 1.1544 - accuracy: 0.5286 - val_loss: 1.1804 - val_accuracy: 0.5600
# Epoch 16/90
# 6/6 [==============================] - 4s 665ms/step - loss: 1.1343 - accuracy: 0.5229 - val_loss: 1.1525 - val_accuracy: 0.5500
# Epoch 17/90
# 6/6 [==============================] - 4s 660ms/step - loss: 1.0949 - accuracy: 0.5543 - val_loss: 1.1178 - val_accuracy: 0.5200
# Epoch 18/90
# 6/6 [==============================] - 4s 659ms/step - loss: 1.0841 - accuracy: 0.5800 - val_loss: 1.1753 - val_accuracy: 0.5200
# Epoch 19/90
# 6/6 [==============================] - 4s 664ms/step - loss: 1.0558 - accuracy: 0.5943 - val_loss: 1.0812 - val_accuracy: 0.5700
# Epoch 20/90
# 6/6 [==============================] - 4s 666ms/step - loss: 1.0166 - accuracy: 0.5829 - val_loss: 1.1159 - val_accuracy: 0.5800
# Epoch 21/90
# 6/6 [==============================] - 4s 706ms/step - loss: 1.0310 - accuracy: 0.5857 - val_loss: 1.0722 - val_accuracy: 0.5700
# Epoch 22/90
# 6/6 [==============================] - 4s 663ms/step - loss: 0.9563 - accuracy: 0.6286 - val_loss: 1.0640 - val_accuracy: 0.5700
# Epoch 23/90
# 6/6 [==============================] - 4s 669ms/step - loss: 0.9542 - accuracy: 0.6286 - val_loss: 1.1167 - val_accuracy: 0.5600
# Epoch 24/90
# 6/6 [==============================] - 4s 666ms/step - loss: 0.9192 - accuracy: 0.6286 - val_loss: 1.2120 - val_accuracy: 0.5300
# Epoch 25/90
# 6/6 [==============================] - 4s 663ms/step - loss: 0.9288 - accuracy: 0.6486 - val_loss: 1.0707 - val_accuracy: 0.6200
# Epoch 26/90
# 6/6 [==============================] - 4s 662ms/step - loss: 0.8724 - accuracy: 0.6600 - val_loss: 1.0706 - val_accuracy: 0.5900
# Epoch 27/90
# 6/6 [==============================] - 4s 666ms/step - loss: 0.8927 - accuracy: 0.6743 - val_loss: 1.1968 - val_accuracy: 0.5200
# Epoch 28/90
# 6/6 [==============================] - 4s 667ms/step - loss: 0.9016 - accuracy: 0.6400 - val_loss: 1.1089 - val_accuracy: 0.5900
# Epoch 29/90
# 6/6 [==============================] - 4s 666ms/step - loss: 0.8204 - accuracy: 0.6771 - val_loss: 1.0205 - val_accuracy: 0.6200
# Epoch 30/90
# 6/6 [==============================] - 4s 665ms/step - loss: 0.7763 - accuracy: 0.6943 - val_loss: 1.0465 - val_accuracy: 0.6200
# Epoch 31/90
# 6/6 [==============================] - 4s 664ms/step - loss: 0.7367 - accuracy: 0.7457 - val_loss: 1.0409 - val_accuracy: 0.6700
# Epoch 51/90
# 6/6 [==============================] - 4s 666ms/step - loss: 0.3646 - accuracy: 0.8571 - val_loss: 1.2723 - val_accuracy: 0.6500
# Epoch 52/90
# 6/6 [==============================] - 4s 665ms/step - loss: 0.4060 - accuracy: 0.8429 - val_loss: 1.2690 - val_accuracy: 0.6800
# Epoch 53/90
# 6/6 [==============================] - 4s 664ms/step - loss: 0.5218 - accuracy: 0.8057 - val_loss: 1.2311 - val_accuracy: 0.6100
# Epoch 54/90
# 6/6 [==============================] - 4s 665ms/step - loss: 0.3940 - accuracy: 0.8629 - val_loss: 1.2560 - val_accuracy: 0.6600
# Epoch 55/90
# 6/6 [==============================] - 4s 665ms/step - loss: 0.3599 - accuracy: 0.8571 - val_loss: 1.3350 - val_accuracy: 0.6500
# Epoch 55: early stopping

# %%
predictions_2 = model_2.predict(X_test)

# Compute the confusion matrix
cm_2 = confusion_matrix(np.argmax(Y_test, axis=-1), np.argmax(predictions_2, axis=-1))

# Compute the classification metrics
accuracy_2 = accuracy_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_2, axis=-1))
precision_2 = precision_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_2, axis=-1), average='macro')
recall_2 = recall_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_2, axis=-1), average='macro')
f1_2 = f1_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_2, axis=-1), average='macro')
print('Accuracy:',accuracy_2.round(4))
print('Precision:',precision_2.round(4))
print('Recall:',recall_2.round(4))
print('F1:',f1_2.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_2.T)#, xticklabels=list(labels.values()), yticklabels=list(labels.values()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.62
# Precision: 0.6244
# Recall: 0.62
# F1: 0.6048

# %% [markdown]
# ### Model 2 with rectangular filters, adaptive learning

# %%
def build_model_3(input_shape, n_units):
# Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        filters=16,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    pool1 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv1)

    conv2 = tfkl.Conv2D(
        filters=32,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    pool2 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv2)

    conv3 = tfkl.Conv2D(
        filters=64,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        filters=64,
        kernel_size=(2, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    pool4 = tfkl.MaxPooling2D(
        pool_size = (2, 3)
    )(conv4)

    conv5 = tfkl.Conv2D(
        filters=128,
        kernel_size=(1, 2),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        pool_size = (2, 3)
    )(conv5)


    flattening_layer = tfkl.Flatten(name='Flatten')(pool5)
    flattening_layer = tfkl.Dropout(0.2, seed=seed)(flattening_layer)
    classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(flattening_layer)
    classifier_layer = tfkl.Dropout(0.2, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=n_units, activation='softmax', name='Output')(classifier_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model

    return model

# %%
input_shape = (128, 2559, 1)

model_3 = build_model_3(input_shape, n_genres)

model_3.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 128, 2559, 1)]    0
#
#  conv2d_23 (Conv2D)          (None, 128, 2559, 16)     112
#
#  max_pooling2d_15 (MaxPoolin  (None, 64, 1279, 16)     0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 64, 1279, 32)      3104
#
#  max_pooling2d_16 (MaxPoolin  (None, 32, 639, 32)      0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 639, 64)       12352
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 319, 64)      0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 319, 64)       24640
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 106, 64)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 8, 106, 128)       16512
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 35, 128)       0
#  g2D)
#
#  Flatten (Flatten)           (None, 17920)             0
#
#  dropout_8 (Dropout)         (None, 17920)             0
#
#  Classifier (Dense)          (None, 64)                1146944
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  Output (Dense)              (None, 5)                 325
#
# =================================================================
# Total params: 1,203,989
# Trainable params: 1,203,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True)
adaptive_LR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-4)

standard_history_3 = model_3.fit(
    x = X_train,
    y = Y_train,
    epochs = 500,
    batch_size = 64,
    validation_data= (X_valid, Y_valid),
    callbacks = [early_stopping, adaptive_LR]
    )
# Out:
# Epoch 1/500
# 6/6 [==============================] - 10s 1s/step - loss: 18.9911 - accuracy: 0.2086 - val_loss: 3.1968 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/500
# 6/6 [==============================] - 4s 694ms/step - loss: 2.0750 - accuracy: 0.2143 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/500
# 6/6 [==============================] - 4s 683ms/step - loss: 1.6119 - accuracy: 0.1943 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/500
# 6/6 [==============================] - 4s 686ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/500
# 6/6 [==============================] - 4s 688ms/step - loss: 1.6111 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 6/500
# 6/6 [==============================] - 4s 682ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 7/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 8/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 9/500
# 6/6 [==============================] - 4s 686ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 10/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 11/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 12/500
# 6/6 [==============================] - 4s 685ms/step - loss: 1.6095 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 13/500
# 6/6 [==============================] - 4s 680ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 14/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 15/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6095 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 16/500
# 6/6 [==============================] - 4s 680ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 17/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 2.5000e-04
# Epoch 18/500
# 6/6 [==============================] - 4s 681ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 19/500
# 6/6 [==============================] - 4s 684ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 20/500
# 6/6 [==============================] - 4s 679ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 21/500
# 6/6 [==============================] - 4s 678ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 1.2500e-04
# Epoch 22/500
# 6/6 [==============================] - 4s 683ms/step - loss: 1.6094 - accuracy: 0.2000 - val_loss: 1.6094 - val_accuracy: 0.2000 - lr: 1.2500e-04

# %%
predictions_3 = model_3.predict(X_test)

# Compute the confusion matrix
cm_3 = confusion_matrix(np.argmax(Y_test, axis=-1), np.argmax(predictions_3, axis=-1))

# Compute the classification metrics
accuracy_3 = accuracy_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_3, axis=-1))
precision_3 = precision_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_3, axis=-1), average='macro')
recall_3 = recall_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_3, axis=-1), average='macro')
f1_3 = f1_score(np.argmax(Y_test, axis=-1), np.argmax(predictions_3, axis=-1), average='macro')
print('Accuracy:',accuracy_3.round(4))
print('Precision:',precision_3.round(4))
print('Recall:',recall_3.round(4))
print('F1:',f1_3.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm_3.T)#, xticklabels=list(labels.values()), yticklabels=list(labels.values()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.2
# Precision: 0.04
# Recall: 0.2
# F1: 0.0667

# %% [markdown]
# ## Saving best model

# %%
model_1.save('/gdrive/MyDrive/Colab Notebooks/NAML/Project/models/Handmade_5_classes_group2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# INFO:tensorflow:Assets written to: /gdrive/MyDrive/Colab Notebooks/NAML/Project/models/Handmade_5_classes_group2/assets
# INFO:tensorflow:Assets written to: /gdrive/MyDrive/Colab Notebooks/NAML/Project/models/Handmade_5_classes_group2/assets
