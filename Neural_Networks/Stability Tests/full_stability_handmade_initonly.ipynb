# %% [markdown]
# ## Black Box Approach for all 10 genres classification
#
# We aim at training a Neural Network to distinguish between all the different genres

# %%
#importing google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#setting the working directory
# %cd /gdrive/MyDrive/polimi/NAML/NAML_proj/
# Out:
# /gdrive/MyDrive/polimi/NAML/NAML_proj

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import os
import random
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
import librosa
import os

tfk = tf.keras
tfkl = tf.keras.layers
seed = 42

# %% [markdown]
# The dataset is composed of Mel-Spectrograms of each audio sample, labeled with respect to each genre

# %%
dataset = []
genres = {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 
        'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}
n_genres = 10

for genre, genre_number in genres.items():
    for filename in os.listdir(f'dataset_old/genres/{genre}'):
        songname = f'dataset_old/genres/{genre}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=29.7)
        ps = librosa.feature.melspectrogram(y=y, sr=sr, hop_length = 256, n_fft = 512)
        ps = librosa.power_to_db(ps**2)
        dataset.append( (ps, genre_number) )
    print(str(genre+' done'))
# Out:
# blues done
# classical done
# country done
# disco done
# hiphop done
# jazz done
# metal done
# pop done
# reggae done
# rock done

# %% [markdown]
# We split the dataset according to the following composition:
#
#
# *   70% training set
# *   20% validation set
# *   10% test set
#
# Maintaining equal proportions amongst classes

# %%
order = np.arange(start = 0, stop = 100, step = 1)

np.random.seed(seed)

training = []
validation = []
test = []

for i in range(n_genres):
  shuffle = np.random.permutation(order)
  for k in range(70):
    training.append(dataset[i*100 + shuffle[k]])
  for l in range(20):
    validation.append(dataset[i*100 + shuffle[l+70]])
  for m in range(10):
    test.append(dataset[i*100 + shuffle[m+90]])

# %%
X_train, Y_train = zip(*training)
X_valid, Y_valid = zip(*validation)
X_test, Y_test = zip(*test)

X_train = np.array([x.reshape( (128, 2559, 1) ) for x in X_train])
X_valid = np.array([x.reshape( (128, 2559, 1) ) for x in X_valid])
X_test = np.array([x.reshape( (128, 2559, 1) ) for x in X_test])


Y_train = np.array(tfk.utils.to_categorical(Y_train, n_genres))
Y_valid = np.array(tfk.utils.to_categorical(Y_valid, n_genres))
Y_test = np.array(tfk.utils.to_categorical(Y_test, n_genres))

# %% [markdown]
# The proposed model is composed as a stack of convolutional layer, followed by a Global Average Pooling layer leading to a fully connected section.
#
# Optimization is performed as a Batch version of Adam optimizer algorithm

# %%
def build_model(input_shape, n_units):
# Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        name = 'conv_1',
        filters=4,
        kernel_size=(5, 5),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    conv1_2 = tfkl.Conv2D(
        name = 'conv_1_2',
        filters=8,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv1)
    pool1 = tfkl.MaxPooling2D(
        name = 'pool_1',
        pool_size = (2, 2)
    )(conv1_2)

    conv2 = tfkl.Conv2D(
        name = 'conv_2',
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    conv2_2 = tfkl.Conv2D(
        name = 'conv_2_2',
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(conv2)
    pool2 = tfkl.MaxPooling2D(
        name = 'pool_2',
        pool_size = (2, 2)
    )(conv2_2)

    conv3 = tfkl.Conv2D(
        name = 'conv_3',
        filters=32,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        name = 'pool_3',
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        name = 'conv_4',
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    pool4 = tfkl.MaxPooling2D(
        name = 'pool_4',
        pool_size = (2, 2)
    )(conv4)

    conv5 = tfkl.Conv2D(
        name = 'conv_5',
        filters=128,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        name = 'pool_5',
        pool_size = (2, 2)
    )(conv5)

    conv6 = tfkl.Conv2D(
        name = 'conv_6',
        filters=286,
        kernel_size=(1, 1),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool5)
    
    global_average = tfkl.GlobalAveragePooling2D(name = 'GAP')(conv6)
    global_average = tfkl.Dropout(0.3, seed=seed, name = 'Dropout_GAP')(global_average)
    
    classifier_layer = tfkl.Dense(units=64, name='Classifier', activation='relu')(global_average)
    
    classifier_layer = tfkl.Dropout(0.3, seed=seed, name = 'Dropout_Classifier')(classifier_layer)
    classifier_layer_2 = tfkl.Dense(units=32, name='Classifier_2', activation='relu')(classifier_layer)
    classifier_layer_2 = tfkl.Dropout(0.3, seed=seed, name = 'Dropout_Classifier_2')(classifier_layer_2)
    output_layer = tfkl.Dense(units=n_units, activation='softmax', name='Output')(classifier_layer_2)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model

    return model

# %%
metrics_accuracy = []
metrics_precision = []
metrics_recall = []
metrics_f1 = []

n_trials = 10
input_shape = (128, 2559, 1)
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True)
adaptive_LR = tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-4)

for i in range(n_trials):
  model = build_model(input_shape, n_genres)
  standard_history = model.fit(
    x = X_train,
    y = Y_train,
    epochs = 500,
    batch_size = 100,
    validation_data= (X_valid, Y_valid),
    callbacks = [early_stopping, adaptive_LR]
    )
  predictions = model.predict(X_test)
  metrics_accuracy.append(accuracy_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1)))
  metrics_precision.append(precision_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro'))
  metrics_recall.append(recall_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro'))
  metrics_f1.append(f1_score(np.argmax(Y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro'))
  model.save(str('/gdrive/MyDrive/polimi/NAML/NAML_proj/models/stability/complete_0_'+str(i)))
# Out:
# Epoch 1/500
# 7/7 [==============================] - 29s 2s/step - loss: 2.3472 - accuracy: 0.1043 - val_loss: 2.3013 - val_accuracy: 0.1000 - lr: 0.0010
# Epoch 2/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.3076 - accuracy: 0.1000 - val_loss: 2.3005 - val_accuracy: 0.0950 - lr: 0.0010
# Epoch 3/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.3008 - accuracy: 0.1086 - val_loss: 2.2990 - val_accuracy: 0.0500 - lr: 0.0010
# Epoch 4/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2981 - accuracy: 0.1029 - val_loss: 2.2923 - val_accuracy: 0.0800 - lr: 0.0010
# Epoch 5/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2864 - accuracy: 0.1343 - val_loss: 2.2756 - val_accuracy: 0.0700 - lr: 0.0010
# Epoch 6/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2733 - accuracy: 0.1000 - val_loss: 2.2393 - val_accuracy: 0.0800 - lr: 0.0010
# Epoch 7/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2448 - accuracy: 0.1257 - val_loss: 2.1837 - val_accuracy: 0.1600 - lr: 0.0010
# Epoch 8/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2129 - accuracy: 0.1514 - val_loss: 2.1425 - val_accuracy: 0.1850 - lr: 0.0010
# Epoch 9/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.
500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2554 - accuracy: 0.1514 - val_loss: 2.1625 - val_accuracy: 0.2300 - lr: 5.0000e-04
# Epoch 14/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.2211 - accuracy: 0.1743 - val_loss: 2.1167 - val_accuracy: 0.1900 - lr: 5.0000e-04
# Epoch 15/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.1992 - accuracy: 0.1657 - val_loss: 2.1348 - val_accuracy: 0.2000 - lr: 5.0000e-04
# Epoch 16/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.1800 - accuracy: 0.1929 - val_loss: 2.0717 - val_accuracy: 0.2500 - lr: 5.0000e-04
# Epoch 17/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.1411 - accuracy: 0.2043 - val_loss: 2.0330 - val_accuracy: 0.2550 - lr: 5.0000e-04
# Epoch 18/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.0944 - accuracy: 0.2157 - val_loss: 1.9898 - val_accuracy: 0.2650 - lr: 5.0000e-04
# Epoch 19/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.0634 - accuracy: 0.2186 - val_loss: 1.9536 - val_accuracy: 0.2750 - lr: 5.0000e-04
# Epoch 20/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.0839 - accuracy: 0.2100 - val_loss: 1.9373 - val_accuracy: 0.2850 - lr: 5.0000e-04
# Epoch 21/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.1072 - accuracy: 0.1943 - val_loss: 1.9693 - val_accuracy: 0.2950 - lr: 5.0000e-04
# Epoch 22/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.0344 - accuracy: 0.2357 - val_loss: 1.9324 - val_accuracy: 0.3300 - lr: 5.0000e-04
# Epoch 23/500
# 7/7 [==============================] - 10s 1s/step - loss: 2.0132 - accuracy: 0.2386 - val_loss: 1.8698 - val_accuracy: 0.2950 - lr: 5.0000e-04
# Epoch 24/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.9356 - accuracy: 0.2786 - val_loss: 1.8012 - val_accuracy: 0.3550 - lr: 5.0000e-04
# Epoch 25/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.9583 - accuracy: 0.2486 - val_loss: 1.7761 - val_accuracy: 0.3500 - lr: 5.0000e-04
# Epoch 26/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.9204 - accuracy: 0.2743 - val_loss: 1.7619 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 27/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.9526 - accuracy: 0.2729 - val_loss: 1.7557 - val_accuracy: 0.3850 - lr: 5.0000e-04
# Epoch 28/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.9003 - accuracy: 0.2829 - val_loss: 1.7116 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 29/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.8625 - accuracy: 0.3014 - val_loss: 1.7049 - val_accuracy: 0.3850 - lr: 5.0000e-04
# Epoch 30/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.8645 - accuracy: 0.2871 - val_loss: 1.6730 - val_accuracy: 0.4050 - lr: 5.0000e-04
# Epoch 31/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.8660 - accuracy: 0.3100 - val_loss: 1.6593 - val_accuracy: 0.4050 - lr: 5.0000e-04
# Epoch 32/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.8358 - accuracy: 0.2971 - val_loss: 1.6592 - val_accuracy: 0.4100 - lr: 5.0000e-04
# Epoch 33/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.8086 - accuracy: 0.3214 - val_loss: 1.6313 - val_accuracy: 0.4500 - lr: 5.0000e-04
# Epoch 34/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.7798 - accuracy: 0.3229 - val_loss: 1.5875 - val_accuracy: 0.4100 - lr: 5.0000e-04
# Epoch 35/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.7746 - accuracy: 0.3243 - val_loss: 1.5470 - val_accuracy: 0.4850 - lr: 5.0000e-04
# Epoch 36/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.7871 - accuracy: 0.3243 - val_loss: 1.6232 - val_accuracy: 0.4550 - lr: 5.0000e-04
# Epoch 37/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.7750 - accuracy: 0.3443 - val_loss: 1.6063 - val_accuracy: 0.4350 - lr: 5.0000e-04
# Epoch 38/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.
500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2772 - accuracy: 0.5529 - val_loss: 1.1899 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 68/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2877 - accuracy: 0.5557 - val_loss: 1.1180 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 69/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2132 - accuracy: 0.5586 - val_loss: 1.1292 - val_accuracy: 0.6750 - lr: 5.0000e-04
# Epoch 70/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1729 - accuracy: 0.6000 - val_loss: 1.1041 - val_accuracy: 0.6650 - lr: 5.0000e-04
# Epoch 71/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.1178 - accuracy: 0.6229 - val_loss: 1.0883 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 72/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1251 - accuracy: 0.6257 - val_loss: 1.1496 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 73/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.1545 - accuracy: 0.6043 - val_loss: 1.1341 - val_accuracy: 0.6650 - lr: 5.0000e-04
# Epoch 74/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0796 - accuracy: 0.6286 - val_loss: 1.0905 - val_accuracy: 0.6550 - lr: 5.0000e-04
# Epoch 75/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0648 - accuracy: 0.6429 - val_loss: 1.1274 - val_accuracy: 0.6300 - lr: 5.0000e-04
# Epoch 76/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1262 - accuracy: 0.6029 - val_loss: 1.1153 - val_accuracy: 0.6500 - lr: 5.0000e-04
# Epoch 77/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.1396 - accuracy: 0.6400 - val_loss: 1.0739 - val_accuracy: 0.6600 - lr: 2.5000e-04
# Epoch 78/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.0787 - accuracy: 0.6386 - val_loss: 1.0603 - val_accuracy: 0.6850 - lr: 2.5000e-04
# Epoch 79/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0332 - accuracy: 0.6543 - val_loss: 1.0531 - val_accuracy: 0.6750 - lr: 2.5000e-04
# Epoch 80/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0233 - accuracy: 0.6657 - val_loss: 1.0462 - val_accuracy: 0.6650 - lr: 2.5000e-04
# Epoch 81/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0319 - accuracy: 0.6471 - val_loss: 1.0601 - val_accuracy: 0.6700 - lr: 2.5000e-04
# Epoch 82/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.0375 - accuracy: 0.6400 - val_loss: 1.0942 - val_accuracy: 0.6700 - lr: 2.5000e-04
# Epoch 83/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0331 - accuracy: 0.6429 - val_loss: 1.0577 - val_accuracy: 0.6800 - lr: 2.5000e-04
# Epoch 84/500
# ...
# Epoch 30/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.5669 - accuracy: 0.4071 - val_loss: 1.4522 - val_accuracy: 0.4550 - lr: 0.0010
# Epoch 31/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.5418 - accuracy: 0.4486 - val_loss: 1.6329 - val_accuracy: 0.3900 - lr: 0.0010
# Epoch 32/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.5823 - accuracy: 0.4300 - val_loss: 1.6223 - val_accuracy: 0.3750 - lr: 0.0010
# Epoch 33/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.5764 - accuracy: 0.4457 - val_loss: 1.4114 - val_accuracy: 0.4950 - lr: 0.0010
# Epoch 34/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.4829 - accuracy: 0.4714 - val_loss: 1.3908 - val_accuracy: 0.5300 - lr: 5.0000e-04
# Epoch 35/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.4348 - accuracy: 0.4757 - val_loss: 1.3391 - val_accuracy: 0.5050 - lr: 5.0000e-04
# Epoch 36/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.3990 - accuracy: 0.5071 - val_loss: 1.3273 - val_accuracy: 0.5500 - lr: 5.0000e-04
# Epoch 37/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3613 - accuracy: 0.5071 - val_loss: 1.3113 - val_accuracy: 0.5300 - lr: 5.0000e-04
# Epoch 38/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3399 - accuracy: 0.5171 - val_loss: 1.3156 - val_accuracy: 0.5550 - lr: 5.0000e-04
# Epoch 39/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3567 - accuracy: 0.5000 - val_loss: 1.2990 - val_accuracy: 0.5700 - lr: 5.0000e-04
# Epoch 40/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3788 - accuracy: 0.4914 - val_loss: 1.2638 - val_accuracy: 0.5500 - lr: 5.0000e-04
# Epoch 41/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.3920 - accuracy: 0.4729 - val_loss: 1.3951 - val_accuracy: 0.4500 - lr: 5.0000e-04
# Epoch 42/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3214 - accuracy: 0.5200 - val_loss: 1.2441 - val_accuracy: 0.5650 - lr: 5.0000e-04
# Epoch 43/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3254 - accuracy: 0.5071 - val_loss: 1.2572 - val_accuracy: 0.5450 - lr: 5.0000e-04
# Epoch 44/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2756 - accuracy: 0.5357 - val_loss: 1.2144 - val_accuracy: 0.5750 - lr: 5.0000e-04
# Epoch 45/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.3126 - accuracy: 0.5343 - val_loss: 1.2196 - val_accuracy: 0.5950 - lr: 5.0000e-04
# Epoch 46/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.2807 - accuracy: 0.5414 - val_loss: 1.2143 - val_accuracy: 0.5550 - lr: 5.0000e-04
# Epoch 47/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.2520 - accuracy: 0.5486 - val_loss: 1.1915 - val_accuracy: 0.6100 - lr: 5.0000e-04
# Epoch 48/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2417 - accuracy: 0.5514 - val_loss: 1.1910 - val_accuracy: 0.5950 - lr: 5.0000e-04
# Epoch 49/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2444 - accuracy: 0.5600 - val_loss: 1.2005 - val_accuracy: 0.6150 - lr: 5.0000e-04
# Epoch 50/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.1914 - accuracy: 0.5571 - val_loss: 1.1731 - val_accuracy: 0.6150 - lr: 5.0000e-04
# Epoch 51/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2376 - accuracy: 0.5729 - val_loss: 1.1535 - val_accuracy: 0.6050 - lr: 5.0000e-04
# Epoch 52/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1846 - accuracy: 0.5729 - val_loss: 1.1684 - val_accuracy: 0.5700 - lr: 5.0000e-04
# Epoch 53/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2472 - accuracy: 0.5500 - val_loss: 1.2384 - val_accuracy: 0.5050 - lr: 5.0000e-04
# Epoch 54/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2484 - accuracy: 0.5329 - val_loss: 1.2617 - val_accuracy: 0.5100 - lr: 5.0000e-04
# Epoch 55/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2676 - accuracy: 0.5529 - val_loss: 1.1902 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 56/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2459 - accuracy: 0.5643 - val_loss: 1.2366 - val_accuracy: 0.6050 - lr: 5.0000e-04
# Epoch 57/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.2418 - accuracy: 0.5700 - val_loss: 1.1510 - val_accuracy: 0.5800 - lr: 2.5000e-04
# Epoch 58/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1540 - accuracy: 0.5957 - val_loss: 1.1234 - val_accuracy: 0.6400 - lr: 2.5000e-04
# Epoch 59/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1742 - accuracy: 0.5914 - val_loss: 1.1273 - val_accuracy: 0.6150 - lr: 2.5000e-04
# Epoch 60/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.1070 - accuracy: 0.6229 - val_loss: 1.1109 - val_accuracy: 0.6150 - lr: 2.5000e-04
# Epoch 61/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1281 - accuracy: 0.5886 - val_loss: 1.1086 - val_accuracy: 0.6600 - lr: 2.5000e-04
# Epoch 62/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1569 - accuracy: 0.6000 - val_loss: 1.0932 - val_accuracy: 0.6350 - lr: 2.5000e-04
# Epoch 63/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0880 - accuracy: 0.5971 - val_loss: 1.1121 - val_accuracy: 0.5950 - lr: 2.5000e-04
# Epoch 64/500
# 7/7 [==============================] - 10s 2s/step - loss: 1.0756 - accuracy: 0.6271 - val_loss: 1.1405 - val_accuracy: 0.6650 - lr: 2.5000e-04
# Epoch 65/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.1168 - accuracy: 0.6029 - val_loss: 1.1065 - val_accuracy: 0.6150 - lr: 2.5000e-04
# Epoch 66/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0752 - accuracy: 0.6129 - val_loss: 1.0879 - val_accuracy: 0.5850 - lr: 2.5000e-04
# Epoch 67/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0612 - accuracy: 0.6114 - val_loss: 1.0608 - val_accuracy: 0.6550 - lr: 2.5000e-04
# Epoch 68/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0576 - accuracy: 0.6271 - val_loss: 1.0621 - val_accuracy: 0.6400 - lr: 2.5000e-04
# Epoch 69/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0623 - accuracy: 0.6357 - val_loss: 1.1180 - val_accuracy: 0.6100 - lr: 2.5000e-04
# Epoch 70/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0965 - accuracy: 0.6357 - val_loss: 1.0322 - val_accuracy: 0.6700 - lr: 2.5000e-04
# Epoch 71/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0730 - accuracy: 0.6229 - val_loss: 1.0602 - val_accuracy: 0.6350 - lr: 2.5000e-04
# Epoch 72/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0668 - accuracy: 0.6371 - val_loss: 1.0667 - val_accuracy: 0.6350 - lr: 2.5000e-04
# Epoch 73/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0468 - accuracy: 0.6471 - val_loss: 1.0263 - val_accuracy: 0.6550 - lr: 2.5000e-04
# Epoch 74/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0953 - accuracy: 0.6343 - val_loss: 1.0944 - val_accuracy: 0.6350 - lr: 2.5000e-04
# Epoch 75/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0676 - accuracy: 0.6271 - val_loss: 1.0454 - val_accuracy: 0.6300 - lr: 2.5000e-04
# Epoch 76/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0803 - accuracy: 0.6300 - val_loss: 1.0853 - val_accuracy: 0.6350 - lr: 2.5000e-04
# Epoch 77/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0011 - accuracy: 0.6600 - val_loss: 1.0356 - val_accuracy: 0.6700 - lr: 2.5000e-04
# Epoch 78/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0253 - accuracy: 0.6529 - val_loss: 1.0470 - val_accuracy: 0.6450 - lr: 2.5000e-04
# Epoch 79/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.9972 - accuracy: 0.6429 - val_loss: 1.0025 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 80/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.9855 - accuracy: 0.6943 - val_loss: 0.9983 - val_accuracy: 0.6900 - lr: 1.2500e-04
# Epoch 81/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9738 - accuracy: 0.6914 - val_loss: 0.9944 - val_accuracy: 0.7100 - lr: 1.2500e-04
# Epoch 82/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9867 - accuracy: 0.6829 - val_loss: 0.9839 - val_accuracy: 0.6800 - lr: 1.2500e-04
# Epoch 83/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9431 - accuracy: 0.6800 - val_loss: 0.9725 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 84/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9858 - accuracy: 0.6657 - val_loss: 0.9805 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 85/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9720 - accuracy: 0.6671 - val_loss: 0.9882 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 86/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9576 - accuracy: 0.6871 - val_loss: 0.9762 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 87/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9777 - accuracy: 0.6529 - val_loss: 0.9690 - val_accuracy: 0.7100 - lr: 1.2500e-04
# Epoch 88/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9734 - accuracy: 0.6657 - val_loss: 0.9771 - val_accuracy: 0.6600 - lr: 1.2500e-04
# Epoch 89/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9916 - accuracy: 0.6700 - val_loss: 0.9544 - val_accuracy: 0.7050 - lr: 1.2500e-04
# Epoch 90/500
# 7/7 [==============================] - 10s 1s/step - loss: 1.0031 - accuracy: 0.6429 - val_loss: 0.9761 - val_accuracy: 0.7150 - lr: 1.2500e-04
# Epoch 91/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9639 - accuracy: 0.6814 - val_loss: 0.9781 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 92/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.9215 - accuracy: 0.7014 - val_loss: 0.9518 - val_accuracy: 0.7200 - lr: 1.2500e-04
# Epoch 93/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9016 - accuracy: 0.6743 - val_loss: 0.9531 - val_accuracy: 0.6750 - lr: 1.2500e-04
# Epoch 94/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8918 - accuracy: 0.7000 - val_loss: 0.9581 - val_accuracy: 0.7100 - lr: 1.2500e-04
# Epoch 95/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.9749 - accuracy: 0.6586 - val_loss: 0.9756 - val_accuracy: 0.6700 - lr: 1.2500e-04
# Epoch 96/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9459 - accuracy: 0.6900 - val_loss: 0.9524 - val_accuracy: 0.6950 - lr: 1.2500e-04
# Epoch 97/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9316 - accuracy: 0.6657 - val_loss: 0.9790 - val_accuracy: 0.7000 - lr: 1.2500e-04
# Epoch 98/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8997 - accuracy: 0.6943 - val_loss: 0.9440 - val_accuracy: 0.6750 - lr: 1.0000e-04
# Epoch 99/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.8997 - accuracy: 0.6986 - val_loss: 0.9806 - val_accuracy: 0.6850 - lr: 1.0000e-04
# Epoch 100/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9078 - accuracy: 0.6843 - val_loss: 0.9539 - val_accuracy: 0.6850 - lr: 1.0000e-04
# Epoch 101/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9374 - accuracy: 0.6814 - val_loss: 0.9588 - val_accuracy: 0.6950 - lr: 1.0000e-04
# Epoch 102/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9712 - accuracy: 0.6586 - val_loss: 0.9549 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 103/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9234 - accuracy: 0.6986 - val_loss: 0.9530 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 104/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9042 - accuracy: 0.6971 - val_loss: 0.9427 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 105/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9187 - accuracy: 0.6900 - val_loss: 0.9572 - val_accuracy: 0.6850 - lr: 1.0000e-04
# Epoch 106/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.9190 - accuracy: 0.7014 - val_loss: 0.9491 - val_accuracy: 0.7050 - lr: 1.0000e-04
# Epoch 107/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9055 - accuracy: 0.6857 - val_loss: 0.9339 - val_accuracy: 0.7050 - lr: 1.0000e-04
# Epoch 108/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.9188 - accuracy: 0.6886 - val_loss: 0.9211 - val_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 109/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8865 - accuracy: 0.6929 - val_loss: 0.9233 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 110/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8993 - accuracy: 0.6757 - val_loss: 0.9294 - val_accuracy: 0.6900 - lr: 1.0000e-04
# Epoch 111/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8706 - accuracy: 0.6900 - val_loss: 0.9311 - val_accuracy: 0.7250 - lr: 1.0000e-04
# Epoch 112/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8798 - accuracy: 0.7029 - val_loss: 0.9250 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 113/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8661 - accuracy: 0.7314 - val_loss: 0.9296 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 114/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8567 - accuracy: 0.7243 - val_loss: 0.9431 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 115/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8952 - accuracy: 0.7000 - val_loss: 0.9216 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 116/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8768 - accuracy: 0.7000 - val_loss: 0.9129 - val_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 117/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8807 - accuracy: 0.6971 - val_loss: 0.9438 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 118/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8737 - accuracy: 0.7100 - val_loss: 0.8981 - val_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 119/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8542 - accuracy: 0.7029 - val_loss: 0.9418 - val_accuracy: 0.6950 - lr: 1.0000e-04
# Epoch 120/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8936 - accuracy: 0.7100 - val_loss: 0.9158 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 121/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8915 - accuracy: 0.7214 - val_loss: 0.9314 - val_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 122/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.8788 - accuracy: 0.7014 - val_loss: 0.9248 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 123/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8828 - accuracy: 0.6914 - val_loss: 0.9002 - val_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 124/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8750 - accuracy: 0.6914 - val_loss: 0.9249 - val_accuracy: 0.6900 - lr: 1.0000e-04
# Epoch 125/500
# 7/7 [==============================] - 10s 2s/step - loss: 0.8398 - accuracy: 0.7343 - val_loss: 0.9138 - val_accuracy: 0.7350 - lr: 1.0000e-04
# Epoch 126/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8645 - accuracy: 0.6943 - val_loss: 0.9285 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 127/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8460 - accuracy: 0.7171 - val_loss: 0.9142 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 128/500
# 7/7 [==============================] - 10s 1s/step - loss: 0.8367 - accuracy: 0.6914 - val_loss: 0.9156 - val_accuracy: 0.7050 - lr: 1.0000e-04
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# INFO:tensorflow:Assets written to: /gdrive/MyDrive/polimi/NAML/NAML_proj/models/stability/complete_0_9/assets
# INFO:tensorflow:Assets written to: /gdrive/MyDrive/polimi/NAML/NAML_proj/models/stability/complete_0_9/assets

# %%
metrics_accuracy = np.array(metrics_accuracy)
metrics_precision = np.array(metrics_precision)
metrics_recall = np.array(metrics_recall)
metrics_f1 = np.array(metrics_f1)

print(str('mean accuracy = ' + str(metrics_accuracy.mean() )))
print(str('mean precision = ' + str(metrics_precision.mean() )))
print(str('mean recall = ' + str(metrics_recall.mean() )))
print(str('mean f1 = ' + str(metrics_f1.mean() )))

print('***___***')

print(str('accuracy standard deviation = ' + str(metrics_accuracy.std() )))
print(str('precision standard deviation = ' + str(metrics_precision.std() )))
print(str('recall standard deviation = ' + str(metrics_recall.std() )))
print(str('f1 standard deviation = ' + str(metrics_f1.std() )))

print('***___***')

print(str('accuracy range = ' + str(metrics_accuracy.max() - metrics_accuracy.min() )))
print(str('precision range = ' + str(metrics_precision.max() - metrics_precision.min() )))
print(str('recall range = ' + str(metrics_recall.max() - metrics_recall.min() )))
print(str('f1 range = ' + str(metrics_f1.max() - metrics_f1.min() )))

print('***___***')

print(str('min accuracy = ' + str(metrics_accuracy.min() )))
print(str('min precision = ' + str(metrics_precision.min() )))
print(str('min recall = ' + str(metrics_recall.min() )))
print(str('min f1 = ' + str(metrics_f1.min() )))
# Out:
# mean accuracy = 0.734
# mean precision = 0.744294511044511
# mean recall = 0.734
# mean f1 = 0.7267590308496487
# ***___***
# accuracy standard deviation = 0.03611094017053559
# precision standard deviation = 0.04364789087156824
# recall standard deviation = 0.03611094017053554
# f1 standard deviation = 0.03861747903338075
# ***___***
# accuracy range = 0.13
# precision range = 0.15380591630591622
# recall range = 0.1299999999999999
# f1 range = 0.14497740426068595
# ***___***
# min accuracy = 0.68
# min precision = 0.6765476190476192
# min recall = 0.68
# min f1 = 0.664448009506833

# %%
print(metrics_accuracy)
print(metrics_precision)
print(metrics_recall)
print(metrics_f1)
# Out:
# [0.72 0.81 0.68 0.71 0.72 0.71 0.76 0.71 0.75 0.77]
# [0.72744589 0.83035354 0.67654762 0.71777778 0.73650794 0.71015956
#  0.79651154 0.71793706 0.74787879 0.7818254 ]
# [0.72 0.81 0.68 0.71 0.72 0.71 0.76 0.71 0.75 0.77]
# [0.716874   0.80942541 0.66444801 0.69744907 0.71259625 0.70409126
#  0.74164665 0.70840203 0.74588517 0.76677245]
